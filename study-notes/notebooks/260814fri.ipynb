# %% [markdown]
# #### Markdown과 가상환경
#
# ---
#
# ##### 오늘의 핵심 요약
#
# - `.md`는 Markdown의 줄임말이다.
# - Markdown 파일에는 내용을 많이 기록할 수 있다.
# - `venv`는 라이브러리를 격리해서 설치하는 별도의 공간이다.
#
# ---
#
# ##### 상세 학습 내용
#
# ---
#
# ##### 1. Markdown 파일
#
# `01_business_rule_template.md`에서 `.md`는 Markdown의 줄임말이다.
#
# Markdown 파일에는 내용을 많이 기록한다.
#
# ```text
# 01_business_rule_template.md
# ```
#
# ---
#
# ##### 2. venv
#
# `venv`는 라이브러리를 격리해서 설치하는 별도의 공간이다.
