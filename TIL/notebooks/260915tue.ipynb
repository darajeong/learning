# %% [markdown]
# #### 2026-09-15
#
# ##### 오늘 한 일
# * pandas로 CSV 데이터를 불러와 결측값과 범주별 분포를 확인하고, 완료 주문 필터링과 데이터 병합 및 그룹별 집계를 실습했다. (Python)
# * PostgreSQL에서 정규화 전후 테이블을 확인하고, JOIN을 이용한 고아 참조 및 중복 데이터 검사와 무결성 제약조건을 학습했다. (SQL)
# * AWS EC2로 Ubuntu 웹 서버를 생성하고, 보안 그룹과 HTTP 포트를 설정한 뒤 Nginx에 HTML 파일을 배포하여 웹페이지 접속을 확인했다. (클라우드)
#
#
# ##### 새롭게 이해한 것
# - 시그모이드와 소프트맥스는 모델의 계산 결과를 확률로 바꾸고, 원핫 인코딩은 범주를 가짜 순서 없이 숫자로 표현하며, BCE·CCE·Sparse CCE는 문제 유형과 정답 표현 방식에 맞춰 예측이 얼마나 틀렸는지 계산한다.
# - 정규화는 각 정보의 진짜 주인을 찾아 테이블을 정리하는 과정으로, 1NF는 한 칸에 값 하나, 2NF는 복합키 일부에만 의존하는 속성 분리, 3NF는 기본키가 아닌 다른 속성에 의존하는 속성 분리를 의미합니다.
#
# ##### 오늘 느낀 점
# * 네 개 조의 프로젝트를 하나로 통합하는 과정에서 구조가 뒤섞여 기존 프로젝트와 이렇게까지 달라질 줄은 몰랐다. 프로젝트를 수정하면서 클라우드 수업까지 병행하느라 바빴지만, HTTP를 통해 실제 사이트가 화면에 나타나는 결과를 보니 재미있었다.
#
# ##### 내일 할 일
# * chapte07 확장 실습 온라인 강의 수강신청 DB 완성하기
# * 3차 프로젝트 통합 대시보드 마지막 점검
