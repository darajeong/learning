# %% [markdown]
# #### 2026-08-19
#
# ##### 오늘 한 일
#
# - 생성형 AI에게 코딩을 질문하는 방법과 Python 기초를 학습했다.
# - VS Code의 코드 구분 방식, 주석, 들여쓰기 오류를 알아봤다.
# - 자세한 내용은 `study-notes/2026-08-19-python-basics.md`에 정리했다.
#
# ##### 새롭게 이해한 것
#
# - Python에서 들여쓰기는 단순한 정렬이 아니라 문법의 일부이다.
# - 주석은 코드의 모든 부분이 아니라 설명이 필요한 부분에 간결하게 작성해야 한다.
#
# ##### 오늘 느낀 점
#
# - 오류를 피하는 것보다 오류를 빠르게 발견하고 원인을 찾아 해결하는 능력이 중요하다고 느꼈다.
