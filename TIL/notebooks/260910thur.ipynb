# %% [markdown]
# #### 2026-09-10
#
# ##### 오늘 한 일
# * Chapter 04 확장 실습 (PostgreSQL에서 학생 테이블을 만들고 데이터를 입력, 조회, 수정, 삭제하면서, SQL을 안전하게 실행하고 결과를 검증하는 방법 실습)
# * [Chapter 05. 요구사항에서 데이터 모델과 ERD 만들기](https://blog.naver.com/dev-dog/224394001915) : 업무 요구사항을 읽고 ERD로 표현하는 데이터 모델링을 학습하였다.
#
#
# ##### 새롭게 이해한 것
# - 과거 데이터를 CSV로 모아 pandas의 DataFrame으로 불러온 뒤 전처리와 EDA를 진행하고, scikit-learn으로 머신러닝 모델을 학습시켜 새로운 데이터의 결과를 예측합니다.
# - pandas에서 `concat`은 여러 표를 이어 붙이고, `join`·`merge`는 공통 값을 기준으로 표를 연결하며, `aggregate`는 여러 값을 평균이나 합계 같은 하나의 통계값으로 요약합니다.
#
# ##### 오늘 느낀 점
# * 복습이 필수다. 오늘 배운 것을 그냥 지나치지 말자. 또한 시간이 허락한다면 예습을 미리 해두어야겠다. 알고 다시 배우는 것과 그냥 듣는 것은 크게 차이가 있는 듯하다.
#
# ##### 내일 할 일
# * Chapter 05 확장 실습 '데이터 전처리'
