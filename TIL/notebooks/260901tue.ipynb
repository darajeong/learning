# %% [markdown]
# #### 템플릿
# #### 2026-09-01
#
# ##### 오늘 한 일
# * [Chapter 23. 개인 지출 관리 프로그램](https://blog.naver.com/dev-dog/224389575441)
# * [개인 지출 관리 프로그램 만들기(Gemini)](https://gemini.google.com/share/9c799aeb7cff?skid=ba91c3f1-5c3c-4bad-a227-be7576259a70)
# [개인 지출 관리 프로그램 만들기(ChatGPT)](https://my-expense-note-2026.bormiiii.chatgpt.site/)
# * 3차 프로젝트 브레인스토밍 시나리오 및 git 협업 의논
#
# ##### 새롭게 이해한 것
# - 결측값은 분석 목적에 따라 삭제하거나 다른 값으로 채우는 등 전처리할 수 있다.
# - GPT와 Gemini는 외부 AI 서버를 API로 사용하고, Ollama는 AI 모델을 내 PC나 서버에서 직접 실행할 수 있게 해준다.
# - 내 Gemini API 키를 쓰면 내 프로젝트의 사용량으로 기록되며, 키는 서버에서 안전하게 관리해야 하고 Gemini 자체는 Google 서버에서 실행되므로 내 PC를 계속 켜둘 필요는 없다.
#
# ##### 오늘 느낀 점
# * 의뢰인에게 발표할 때 논문을 근거로 내용을 구성하면, 의견에 대한 신뢰돌르 높이고 불필요한 이견을 줄일 수 있다.
#
# ##### 내일 할 일
# * 개인 지출 프로그램 업그레이드
# 1) DB연동 : postgresql (Console 연동, Web 연동 -> CSV 제거, DB 공유)
# 2) 공통 함수(.py)를 console 프로그램과 web에서 그대로 재사용 할 것. (django, streamlit)
