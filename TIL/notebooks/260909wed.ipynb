# %% [markdown]
# #### 2026-09-09
#
# ##### 오늘 한 일
# * 데이터베이스 상태를 이해하고 실행후에는 예상대로 만들어졌는지 검증하는 실습을 하였다.
# * chapter 04 확장 실습 과제 '관계형 데이터베이스와 SQL'
#
# ##### 새롭게 이해한 것
# - 소괄호 `()`는 함수·메서드 실행이나 연산 순서 지정에, 대괄호 `[]`는 리스트 생성이나 데이터 선택에, 중괄호 `{}`는 딕셔너리·집합 생성에 사용합니다.
# - pandas에서는 불리언 마스크로 조건에 맞는 행을 고르고, `value_counts()`로 값별 개수, `sum()`으로 합계, `groupby()`로 그룹별 집계, `shape`와 `info()`로 데이터 구조, `isna()`와 `isna().sum()`으로 결측치 여부와 개수, `head()`로 처음 최대 5개 행을 확인합니다.
#
# ##### 오늘 느낀 점
# * 분석을 믿을 수 있게 만드는 데이터 전처리 관련하여 학습하였다. 해당 학습이 SQL을 실행하기 전에 DB 상태 이해와 실행후 예상대로 만들어졌는지 검증하는 것을 배우는데 파이썬 코딩이 너무 어려웠다.
#
# ##### 내일 할 일
# * chapter 02  확장 실습 '데이터와 DBMS 기본개념'
