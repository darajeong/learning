# %% [markdown]
# #### 2026-09-03
#
# ##### 오늘 한 일
# * [데이터의 구조와 DBMS의 역할 학습](https://blog.naver.com/dev-dog/224393674315)
# * 3차 프로젝트: 지금까지 만든 mockup 대시보드의 HTML, CSS, JavaScript를 Django 프로젝트 구조에 맞게 적용해 실제로 진행되는 웹 화면 코드로 구현하는 작업을 위한 준비 단계를 진행함
#
# ##### 새롭게 이해한 것
# - 데이터베이스는 데이터를 저장하고 관리하는 논리적 공간이며, 스키마는 그 안의 테이블, 열, 관계, 제약조건 등의 구조를 정의한 설계도이다.
# - 참조는 한 테이블이 다른 테이블의 데이터를 연결해 사용하는 관계이며, 외래 키는 다른 테이블의 기본 키나 고유 키를 가리켜 그 관계를 구현하는 열이다.
#
# ##### 오늘 느낀 점
# * 아는 것 같이 보여도 아는게 아닐 수 있다. AI를 통해서 문제를 내달라고 하면서 학습하는 것도 좋은 방법인 것 같다.
#
# ##### 내일 할 일
# * [Chapter 02 확장 실습 — 데이터와 DBMS의 기본 개념](https://blog.naver.com/dev-dog/224399504053)
# * [2장 실습. VS Code에서 시작하는 데이터 분석 환경](https://blog.naver.com/dev-dog/224394422807)
# * 파이썬 퀴즈 오답노트 정리하기
