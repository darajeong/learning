# %% [markdown]
# #### 2026-09-08
#
# ##### 오늘 한 일
# * 파이썬으로 폴더를 찾는 문제를 해결하고, 그 코드를 함수와 모듈로 만들어 재사용하는 방법을 학습하였다.
# * 카페 주문 관리 데이터베이스 설계 및 SQL을 실습하였다.
#
# ##### 새롭게 이해한 것
# - 프로젝트 루트 탐색은 현재 작업 폴더부터 부모 폴더를 반복해서 확인하며 `data` 폴더가 있는 위치를 찾는 과정으로, 이를 함수로 만들면 `return`으로 찾은 경로를 돌려주고 여러 곳에서 재사용할 수 있습니다.
# - PostgreSQL은 데이터를 저장하고 SQL 명령을 처리하는 데이터베이스 관리 시스템이며, DBeaver는 PostgreSQL에 연결해 SQL을 전달하고 결과를 화면에 보여주는 관리 도구입니다.
#
# ##### 오늘 느낀 점
# * - 요즘 왜 이렇게 피로가 쌓이는지 모르겠다. 하나를 끝내면 또 다른 과제가 기다리고 있다. 잠시 의욕을 잃기도 했지만, 다시 틈틈이 해나가려 한다. 바쁜 와중에도 꾸준히 해내는 사람들이 있다. 성공과 실패를 가르는 것은 어쩌면 포기하고 싶은 순간에 한 걸음 더 나아가는 작은 차이일지도 모른다. 남들만큼 했다는 생각에 멈추기보다, 내가 할 수 있는 만큼 조금씩 더 나아가고 싶다. 지칠 때는 잠시 쉬더라도 포기하지 않고 끝까지 해내겠다고 다시 한번 다짐한다.
#
# ##### 내일 할 일
# * 심화 학습 과제
