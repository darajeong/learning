# %% [markdown]
# #### 2026-08-28
#
# ##### 오늘 한 일
# * '클래스 - 객체 - 속성 - 메서드'로 같은 구조의 데이터와 기능을 하나로 묶어 관리하는 부분을 학습하였다.
# * Figma로 간단한 대시보드(두쫀쿠 맵)를 생성해봤다.
# * 3차 소규모 프로젝트에 대하여 팀원이 Figma 를 활용하여 프로토타입으로 생성한 홈 화면 대시보드 기능이 잘 나오는지 확인하였다.
#
# ##### 새롭게 이해한 것
# * - `student1.score += 1`을 사용하려면 먼저 `score` 속성에 초기값을 저장해야 하며, 그렇지 않으면 존재하지 않는 속성을 읽으려고 해서 오류가 발생합니다.
# * ERD는 데이터베이스의 테이블과 관계를 나타내는 다이어그램이고, Mermaid는 ERD를 텍스트 코드로 작성하고 그려 주는 문법과 도구입니다.
# * 하드코딩은 바뀔 수 있는 값을 코드에 직접 고정하는 것이며, 실제 대시보드에서는 백엔드가 데이터베이스의 정보를 조회·저장·계산하여 프론트엔드에 전달합니다.
# * Figma는 화면 디자인, Gemini는 빠른 문서·앱 시제품 제작, GPT·Codex는 실제 코드 작성·수정·테스트와 백엔드 연결에 각각 강점이 있습니다.
#
# ##### 오늘 느낀 점
# * Figma, Lovable, Mermaid AI 등 다양한 AI를 쓰임새에 맞게 자유자재로 활용할 수 있는 전문가가 되어야겠다.
# * 튜터님께서 해주신 말씀 중 특히 기억에 남는 이야기가 있다. 행복하게 살아가는 사람들을 연구해 보니, 그들은 나이가 들어서도 꾸준히 무언가를 배우고 있었다고 한다. 나 역시 이 말에 깊이 공감한다. 주변을 둘러보면 나이와 상관없이 눈빛이 또렷하고 삶의 목적을 잃지 않은 사람들은 카카오톡 이모티콘을 보내는 사소한 방법부터 새로운 지식과 기술까지 끊임없이 배우며 살아간다. 한 살이라도 젊을 때 배움에 시간과 노력을 아낌없이 투자해 좋은 성과를 만들어 가자.
#
# ##### 내일 할 일
# * 프로그래머스 코딩테스트 활용해보기
